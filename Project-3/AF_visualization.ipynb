# %%
from my_plotting_functions import plot_AFs

# %%
# data for plotting
# 10 querys, each list contains 10 results.

lsh_AF = [1.41735, 1.19683, 3.86118, 1.62426, 1.36545, 3.7373, 1.63842, 1.16502, 1.21648, 1.81837]
lsh_average = 1.90407

cube_AF = [2.05392, 2.20667, 2.69655, 1.33528, 1.59172, 2.89068, 1.12926, 1.73564, 1.1129, 1.95559]
cube_average = 1.87082

gnns_AF = [3.033, 1.52369, 5.0698, 1.91739, 1.45048, 4.05837, 1.42769, 1.56381, 1.2427, 1.66436]
gnns_average = 2.29513

mrng_AF = [1.45972, 1.31866, 1.20999, 1.7959, 1.29909, 1.66812, 1.74626, 1.24744, 2.35098, 1.56267]
mrgn_average = 1.565883

queries = len(lsh_AF)

# %%
# plot the AFs
plot_AFs(queries, [lsh_AF, cube_AF, gnns_AF, mrng_AF], [lsh_average, cube_average, gnns_average, mrgn_average])
